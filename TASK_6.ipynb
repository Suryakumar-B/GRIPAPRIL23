# %% [markdown]
# # **GRIP**
# # **The Sparks Foundation**
# # Task 6:
# # Prediction Using Decision Tree
#
#
# ## **By: Suryakumar.B**

# %%
# Importing libraries in Python

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn import datasets
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
import pydotplus
from IPython.display import Image

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# %%
iris = datasets.load_iris()

df = pd.DataFrame(iris.data, columns=iris.feature_names)

df['Target']=iris.target

df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    Target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
df.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)      Target
# count        150.000000  150.000000
# mean           1.199333    1.000000
# std            0.762238    0.819232
# min            0.100000    0.000000
# 25%            0.300000    0.000000
# 50%            1.300000    1.000000
# 75%            1.800000    2.000000
# max            2.500000    2.000000

# %%
df.isna().sum()
# Out:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# Target               0
# dtype: int64

# %%
df_num = df.drop('Target',1)
df_cat = df['Target']
# Out:
# <ipython-input-5-dc736a638bef>:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df_num = df.drop('Target',1)

# %%
for i in df_num.columns:
  sns.kdeplot(x=df[i])
  plt.title(i)
  plt.show()

# %%
sns.countplot(x=df['Target'])
plt.title('Target')
plt.show()

# %%
x = df.drop('Target',1)
y=df['Target']
# Out:
# <ipython-input-8-8fb3e193df6b>:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   x = df.drop('Target',1)

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y,random_state=10,test_size = 0.2)

print('xtrain', xtrain.shape)
print('ytrain', ytrain.shape)

# print dimension of test set
print('xtest', xtest.shape)
print('ytest', ytest.shape)
# Out:
# xtrain (120, 4)
# ytrain (120,)
# xtest (30, 4)
# ytest (30,)

# %%
def get_train_report(model):
  ypred_train = model.predict(xtrain)
  return(classification_report(ytrain, ypred_train))

# %%
def get_test_report(model):
    ypred_test = model.predict(xtest)
    return(classification_report(ytest, ypred_test))

# %%
dt=DecisionTreeClassifier().fit(xtrain,ytrain)

# %%
tree.plot_tree(dt,max_depth=3,feature_names=xtrain.columns,rounded=True)
plt.show()

# %%
print(get_train_report(dt))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        40
#            1       1.00      1.00      1.00        37
#            2       1.00      1.00      1.00        43
#
#     accuracy                           1.00       120
#    macro avg       1.00      1.00      1.00       120
# weighted avg       1.00      1.00      1.00       120

# %%
print(get_test_report(dt))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       1.00      0.92      0.96        13
#            2       0.88      1.00      0.93         7
#
#     accuracy                           0.97        30
#    macro avg       0.96      0.97      0.96        30
# weighted avg       0.97      0.97      0.97        30
